# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("/content/symptoms dataset.csv")

# %%
df.head()
# Out:
#    Disease         Symptom_1  Symptom_2             Symptom_3  \
# 0        0  Fungal infection    itching             skin_rash
# 1        1  Fungal infection  skin_rash  nodal_skin_eruptions
# 2        2  Fungal infection    itching  nodal_skin_eruptions
# 3        3  Fungal infection    itching             skin_rash
# 4        4  Fungal infection    itching             skin_rash
#
#               Symptom_4            Symptom_5  Symptom_6  Symptom_7  Symptom_8  \
# 0  nodal_skin_eruptions  dischromic _patches        NaN        NaN        NaN
# 1   dischromic _patches                  NaN        NaN        NaN        NaN
# 2   dischromic _patches                  NaN        NaN        NaN        NaN
# 3   dischromic _patches                  NaN        NaN        NaN        NaN
# 4  nodal_skin_eruptions                  NaN        NaN        NaN        NaN
#
#    Symptom_9  Symptom_10  Symptom_11  Symptom_12  Symptom_13  Symptom_14  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN         NaN         NaN
#
#    Symptom_15  Symptom_16  Symptom_17  Symptoms  \
# 0         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN       NaN
# 2         NaN         NaN         NaN       NaN
# 3         NaN         NaN         NaN       NaN
# 4         NaN         NaN         NaN       NaN
#
#                                        Unnamed: 19
# 0   [itching, skin_rash, nodal_skin_eruptions, ...
# 1  [ skin_rash, nodal_skin_eruptions, dischromi...
# 2  [itching, nodal_skin_eruptions, dischromic _...
# 3  [itching, skin_rash, dischromic _patches, na...
# 4  [itching, skin_rash, nodal_skin_eruptions, n...

# %%
df["Symptoms "] = 0

# %%
df.head(5)
# Out:
#    Disease         Symptom_1  Symptom_2             Symptom_3  \
# 0        0  Fungal infection    itching             skin_rash
# 1        1  Fungal infection  skin_rash  nodal_skin_eruptions
# 2        2  Fungal infection    itching  nodal_skin_eruptions
# 3        3  Fungal infection    itching             skin_rash
# 4        4  Fungal infection    itching             skin_rash
#
#               Symptom_4            Symptom_5  Symptom_6  Symptom_7  Symptom_8  \
# 0  nodal_skin_eruptions  dischromic _patches        NaN        NaN        NaN
# 1   dischromic _patches                  NaN        NaN        NaN        NaN
# 2   dischromic _patches                  NaN        NaN        NaN        NaN
# 3   dischromic _patches                  NaN        NaN        NaN        NaN
# 4  nodal_skin_eruptions                  NaN        NaN        NaN        NaN
#
#    Symptom_9  ...  Symptom_11  Symptom_12  Symptom_13  Symptom_14  Symptom_15  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 4        NaN  ...         NaN         NaN         NaN         NaN         NaN
#
#    Symptom_16  Symptom_17  Symptoms  \
# 0         NaN         NaN         0
# 1         NaN         NaN         0
# 2         NaN         NaN         0
# 3         NaN         NaN         0
# 4         NaN         NaN         0
#
#                                        Unnamed: 19 Symptoms
# 0   [itching, skin_rash, nodal_skin_eruptions, ...         0
# 1  [ skin_rash, nodal_skin_eruptions, dischromi...         0
# 2  [itching, nodal_skin_eruptions, dischromic _...         0
# 3  [itching, skin_rash, dischromic _patches, na...         0
# 4  [itching, skin_rash, nodal_skin_eruptions, n...         0
#
# [5 rows x 21 columns]

# %%
column_values = df[['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
       'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9',
       'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14',
       'Symptom_15', 'Symptom_16', 'Symptom_17']].values.ravel()

# %%
symps = pd.unique(column_values)
symps = symps.tolist()
symps = [i for i in symps if str(i) != "nan"]

# %%
symptoms = pd.DataFrame(columns = symps,index = df.index)

# %%
symptoms
# Out:
#   Fungal infection itching skin_rash nodal_skin_eruptions dischromic _patches
# 0              NaN     NaN       NaN                  NaN                 NaN
# 1              NaN     NaN       NaN                  NaN                 NaN
# 2              NaN     NaN       NaN                  NaN                 NaN
# 3              NaN     NaN       NaN                  NaN                 NaN
# 4              NaN     NaN       NaN                  NaN                 NaN

# %%
symptoms["Symptoms"] = df["Symptoms"]
